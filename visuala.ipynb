# %%
import seaborn as sns
import pandas as pd

# %%
pat=pd.read_csv("C:\\Users\\Hi\\Documents\\python\\data\\country_population.csv")
pats=pat.head(5)
print(pats)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %%
bod=pd.read_csv("C:\\Users\\Hi\\Documents\\python\\data\\country_population.csv")
bods=bod.head(5)
print(bods)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2012         2013         2014         2015  \
# ...

# %%
sns.barplot(x="Country Code",y="2020",data=pats, palette="YlGnBu",)
# Out:
# <Axes: xlabel='Country Code', ylabel='2020'>

# %%
sns.histplot(x="Country Code",y="1960",data=pats, palette="YlGnBu",)
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_5132\3165966932.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x="Country Code",y="1960",data=pats, palette="YlGnBu",)
# <Axes: xlabel='Country Code', ylabel='1960'>

# %%
sns.boxplot(x="Country Code",y="1960",data=pats, palette="YlGnBu",)
# Out:
# <Axes: xlabel='Country Code', ylabel='1960'>

# %%
sns.scatterplot(x="1960",y="1961",data=bod)
# Out:
# <Axes: xlabel='1960', ylabel='1961'>

# %%
sns.stripplot(x="1961",y="1960",data=pats, palette="YlGnBu",hue="Country Code")
# Out:
# <Axes: xlabel='1961', ylabel='1960'>

# %%
sns.boxplot(x="1960",y="1961",data=bod)
# Out:
# <Axes: xlabel='1960', ylabel='1961'>

# %%
pod=pd.read_csv("C:\\Users\\Hi\\Documents\\python\\data\\combinedCleaned.csv")
pods=pod.head(6)
print(pods)
# Out:
#    PHY102  MTS104  EEE201  EEE202  output
# 0    60.0    70.0    57.0    64.0   51.50
# 1    55.0    61.0    54.0    74.0   55.50
# 2    68.0    54.0    44.0    52.0   51.50
# 3    67.0    74.0    75.0    54.0   64.75
# 4    56.0    72.0    66.0    60.0   62.00
# 5    83.0    74.0    73.0    69.0   66.75

# %%
sns.scatterplot(x="PHY102",y="output",data=pods, palette="YlGnBu",)
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_5132\1699510154.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="PHY102",y="output",data=pods, palette="YlGnBu",)
# <Axes: xlabel='PHY102', ylabel='output'>

# %%
sns.barplot(x="PHY102",y="output",data=pods, palette="YlGnBu",)
# Out:
# <Axes: xlabel='PHY102', ylabel='output'>

# %%
sns.boxplot(x="PHY102",y="MTS104",data=pods, palette="YlGnBu",)
# Out:
# <Axes: xlabel='PHY102', ylabel='MTS104'>

# %%
sns.distplot(pods["output"], kde=True, bins=10)
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_5132\4132125859.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pods["output"], kde=True, bins=10)
# <Axes: xlabel='output', ylabel='Density'>

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
