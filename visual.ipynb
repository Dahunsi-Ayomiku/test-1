# %%
import pandas as pd
import numpy as np
from statistics import mode
import matplotlib.pyplot as plt
pat="C:\\Users\\Hi\\Documents\\python\\data\\combinedCleaned.csv"
pat
# Out:
# 'C:\\Users\\Hi\\Documents\\python\\data\\combinedCleaned.csv'

# %%
pat=pd.read_csv("C:\\Users\\Hi\\Documents\\python\\data\\combinedCleaned.csv")
pop=pat.head(10)
print(pop)
# Out:
#    PHY102  MTS104  EEE201  EEE202  output
# 0    60.0    70.0    57.0    64.0   51.50
# 1    55.0    61.0    54.0    74.0   55.50
# 2    68.0    54.0    44.0    52.0   51.50
# 3    67.0    74.0    75.0    54.0   64.75
# 4    56.0    72.0    66.0    60.0   62.00
# 5    83.0    74.0    73.0    69.0   66.75
# 6    71.0    71.0    61.0    52.0   61.25
# 7    51.0    50.0    45.0    45.0   24.75
# 8    51.0    51.0    45.0    35.0   23.50
# 9    60.0    61.0    24.0    63.0   48.75

# %%
x=pop["EEE202"]
y=pop["EEE201"]
last=pop["MTS104"]
print(x)
print(y)
# Out:
# 0    64.0
# 1    74.0
# 2    52.0
# 3    54.0
# 4    60.0
# 5    69.0
# 6    52.0
# 7    45.0
# 8    35.0
# 9    63.0
# Name: EEE202, dtype: float64
# 0    57.0
# 1    54.0
# 2    44.0
# 3    75.0
# 4    66.0
# 5    73.0
# 6    61.0
# 7    45.0
# 8    45.0
# 9    24.0
# Name: EEE201, dtype: float64

# %%
plt.plot(x,y)

# %%
plt.hist(x)
# Out:
# (array([1., 0., 1., 0., 3., 0., 1., 2., 1., 1.]),
#  array([35. , 38.9, 42.8, 46.7, 50.6, 54.5, 58.4, 62.3, 66.2, 70.1, 74. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y)
# Out:
# (array([1., 0., 0., 1., 2., 1., 1., 1., 1., 2.]),
#  array([24. , 29.1, 34.2, 39.3, 44.4, 49.5, 54.6, 59.7, 64.8, 69.9, 75. ]),
#  <BarContainer object of 10 artists>)

# %%
barWidth=0.5
plt.bar(np.arange(len(x)),x,width=barWidth,label="EEE202",color="red")
# Out:
# <BarContainer object of 10 artists>

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20864023640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20864023b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x208640233a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x208640580a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20864058340>],
#  'means': []}

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as mp

# %%
plt.scatter( x, y, s=last)

# %%
plt.boxplot(last)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x208643a5f30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x208643a6470>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x208643a5c90>],
#  'medians': [<matplotlib.lines.Line2D at 0x208643a6950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x208643a6bf0>],
#  'means': []}
